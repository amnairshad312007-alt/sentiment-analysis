# %% [markdown]
# <a href="https://colab.research.google.com/github/amnairshad312007-alt/sentiment-analysis/blob/main/Untitleddeep_learning_assignment_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

# %% [markdown]
# Step 2: Upload Dataset

# %%
from google.colab import files
uploaded = files.upload("")
# Out:
#      <input type="file" id="files-95aad459-7dc4-4c3f-abd2-e773d34f8953" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95aad459-7dc4-4c3f-abd2-e773d34f8953">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Test (1).csv")

# %% [markdown]
# Step 3: View Dataset

# %%
df.head()
# Out:
#                                                 text  label
# 0  I always wrote this series off as being a comp...      0
# 1  1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...      0
# 2  This movie was so poorly written and directed ...      0
# 3  The most interesting thing about Miryang (Secr...      1
# 4  when i first read about "berlin am meer" i did...      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    5000 non-null   object
#  1   label   5000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 78.3+ KB

# %%
df.shape
# Out:
# (5000, 2)

# %% [markdown]
# Step 4: Check Missing Values

# %%
df.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# Step 5: Check Target Classes

# %%
df['label'].value_counts()
# Out:
# label
# 1    2505
# 0    2495
# Name: count, dtype: int64

# %% [markdown]
# Visualization:

# %%
sns.countplot(x='label', data=df)
plt.show()

# %% [markdown]
# Step 6: Encode Labels

# %%
encoder = LabelEncoder()

df['label'] = encoder.fit_transform(df['label'])

# %% [markdown]
# Step 7: Features and Target

# %%
X = df['label']
y = df['label']

# %% [markdown]
# Step 8: Tokenization

# %%
tokenizer = Tokenizer(num_words=5000)

tokenizer.fit_on_texts(df['text'])
X_sequences = tokenizer.texts_to_sequences(df['text'])
X = pad_sequences(X_sequences, maxlen=maxlen)

print(f"Shape of tokenized and padded sequences: {X.shape}")
# Out:
# Shape of tokenized and padded sequences: (5000, 100)

# %% [markdown]
# Step 9: Padding

# %%
X_pad = pad_sequences(
    X,
    maxlen=200
)
print(f"Shape of re-padded sequences (X_pad): {X_pad.shape}")
# Out:
# Shape of re-padded sequences (X_pad): (5000, 200)

# %% [markdown]
# Step 10: Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_pad,
    y,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# Step 11: Build Deep Learning Model

# %%
model = Sequential()

model.add(
    Embedding(
        input_dim=5000,
        output_dim=128,
        input_length=200
    )
)

model.add(
    LSTM(64)
)

model.add(
    Dropout(0.5)
)

model.add(
    Dense(1,
    activation='sigmoid')
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %% [markdown]
# Step 12: Compile Model

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Step 13: Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Step 14: Train Model

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=32,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - accuracy: 0.6277 - loss: 0.6453 - val_accuracy: 0.7650 - val_loss: 0.5099
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - accuracy: 0.8425 - loss: 0.3746 - val_accuracy: 0.7880 - val_loss: 0.4470
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.9112 - loss: 0.2276 - val_accuracy: 0.7840 - val_loss: 0.5084
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.9492 - loss: 0.1357 - val_accuracy: 0.7800 - val_loss: 0.7681
# Epoch 5/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.9745 - loss: 0.0853 - val_accuracy: 0.7680 - val_loss: 0.7901

# %% [markdown]
# Step 15: Evaluate Model

# %%
loss, accuracy = model.evaluate(
    X_test,
    y_test
)

print("Accuracy:", accuracy)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7680 - loss: 0.7901
# Accuracy: 0.7680000066757202

# %% [markdown]
# Step 16: Accuracy Graph

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.legend(['Train','Validation'])

plt.show()

# %% [markdown]
# Step 17: Loss Graph

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend(['Train','Validation'])

plt.show()

# %% [markdown]
# Step 18: Prediction

# %%
sample = ["This movie is amazing"]

seq = tokenizer.texts_to_sequences(sample)

pad = pad_sequences(
    seq,
    maxlen=200
)

prediction = model.predict(pad)

print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# [[0.9573498]]
